# %%
import argparse
import os

import numpy as np
import pandas as pd
<

# tf tools
import tensorflow as tf

# scikit-learn
from sklearn.metrics import classification_report

# VGG16 model
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input

# layers
from tensorflow.keras.layers import BatchNormalization, Dense, Dropout, Flatten

# generic model object
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import SGD

# optimizers
from tensorflow.keras.optimizers.schedules import ExponentialDecay

# image processsing
from tensorflow.keras.preprocessing.image import (
    ImageDataGenerator,
    img_to_array,
    load_img,
)

# %%
datagenerator = ImageDataGenerator(
    preprocessing_function=preprocess_input, validation_split=0.2
)

datagenerator_simple_aug = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    horizontal_flip=True,
    rotation_range=20,
    validation_split=0.2,
)

datagenerator_very_aug = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    horizontal_flip=True,
    rotation_range=20,
    zoom_range=[0, 1.25],
    width_shift_range=0.2,
    height_shift_range=0.2,
    validation_split=0.2,
)

# %%
def build_model():
    """
    Build a convolutional neural network using the pretrained VGG16 model as feature extractor. Model has two classification layers and a final output layer.
    Code is adapted from the Session 9 notebook of the Visual Analytics course at AU, 2023.

    Returns:
    A compiled model that can be fit and used for a classification task.

    """

    # load model without classifier layers
    model = VGG16(include_top=False, pooling="avg", input_shape=(224, 224, 3))

    # mark loaded layers as not trainable
    for layer in model.layers:
        layer.trainable = False

    # add new classifier layers
    flat1 = Flatten()(model.layers[-1].output)
    bn = BatchNormalization()(flat1)
    class1 = Dense(256, activation="relu")(bn)
    class2 = Dense(128, activation="relu")(class1)
    output = Dense(4, activation="softmax")(class2)

    # define new model
    model = Model(inputs=model.inputs, outputs=output)

    # compile
    lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
        initial_learning_rate=0.01, decay_steps=10000, decay_rate=0.9
    )
    sgd = SGD(learning_rate=lr_schedule)

    model.compile(optimizer=sgd, loss="categorical_crossentropy", metrics=["accuracy"])

    return model

# %%
def build_model():
    '''
    Build a convolutional neural network using the pretrained VGG16 model as feature extractor. Model has two classification layers and a final output layer.
    Code is adapted from the Session 9 notebook of the Visual Analytics course at AU, 2023.
    
    Returns:
    A compiled model that can be fit and used for a classification task.
    
    '''
    
    # load model without classifier layers
    model = VGG16(include_top=False, 
              pooling='avg',
              input_shape=(224, 224, 3))

    # mark loaded layers as not trainable
    for layer in model.layers:
        layer.trainable = False
    
    # add new classifier layers
    flat1 = Flatten()(model.layers[-1].output)
    bn = BatchNormalization()(flat1)
    class1 = Dense(256, 
                activation='relu')(bn)
    class2 = Dense(128, 
                activation='relu')(class1)
    output = Dense(4, 
                activation='softmax')(class2)

    # define new model
    model = Model(inputs=model.inputs, 
              outputs=output)

    # compile
    lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
        initial_learning_rate=0.01,
        decay_steps=10000,
        decay_rate=0.9)
    sgd = SGD(learning_rate=lr_schedule)

    model.compile(optimizer=sgd,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

    return model


def fit_w_augmentation(generator, model):

    test_datagenerator = ImageDataGenerator(preprocessing_function = preprocess_input)

    train_gen = generator.flow_from_directory(
                directory= os.path.join("Warp-C", "train"),
                target_size = (224, 224),
                color_mode = 'rgb',
                classes = ['cardboard', 'glass', 'metal', 'plastic'],
                shuffle = True, 
                save_to_dir = 'augmented_images',
                save_prefix = 'augmented',
                subset = 'training')

    val_gen = generator.flow_from_directory(
                directory= os.path.join("Warp-C", "train"),
                target_size = (224, 224),
                color_mode = 'rgb',
                shuffle = True, 
                save_to_dir = 'augmented_images',
                save_prefix = 'augmented',
                subset = 'validation')

    test_gen = test_datagenerator.flow_from_directory(        
                directory= os.path.join("Warp-C", "test"),
                target_size = (224, 224),
                color_mode = 'rgb',
                shuffle = False) 

    from sklearn.utils import class_weight

    class_weights = class_weight.compute_class_weight(class_weight = 'balanced',
                                                 classes = np.unique(train_gen.classes),
                                                 y = train_gen.classes)
    
    class_weights = dict(zip(np.unique(train_gen.classes), class_weights))

    model.fit_generator(generator=train_gen, # fit model with generators
                        steps_per_epoch=128,
                        validation_data=val_gen,
                        validation_steps=128,
                        epochs=1, 
                        class_weight = class_weights)
    
    pred = model.predict_generator(test_gen)

    y_true = test_gen.classes

    predicted_classes = np.argmax(pred,axis=1)

    labels = ['cardboard', 'glass', 'metal', 'plastic']

    report = classification_report(y_true,
                            predicted_classes, target_names = labels)
    
    out_path = os.path.join("out", f"{generator}_classification_report.txt")

    with open(out_path, 'w') as file:
                file.write(report)

# %%
model = build_model()

#fit_w_augmentation(datagenerator, model)
#fit_w_augmentation(datagenerator_simple_aug, model)
fit_w_augmentation(datagenerator_very_aug, model)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 2s 0us/step
# Found 7060 images belonging to 4 classes.
# Found 1763 images belonging to 4 classes.
# Found 1521 images belonging to 4 classes.
# /tmp/ipykernel_65/296155082.py:85: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   model.fit_generator(generator=train_gen, # fit model with generators
#  10/128 [=>............................] - ETA: 12:10 - loss: 1.3039 - accuracy: 0.1875
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 5
#       1 model = build_model()
#       3 #fit_w_augmentation(datagenerator, model)
#       4 #fit_w_augmentation(datagenerator_simple_aug, model)
# ----> 5 fit_w_augmentation(datagenerator_very_aug, model)
#
# Cell In[5], line 85, in fit_w_augmentation(generator, model)
#      79 class_weights = class_weight.compute_class_weight(class_weight = 'balanced',
#      80                                              classes = np.unique(train_gen.classes),
#      81                                              y = train_gen.classes)
#      83 class_weights = dict(zip(np.unique(train_gen.classes), class_weights))
# ---> 85 model.fit_generator(generator=train_gen, # fit model with generators
#      86                     steps_per_epoch=128,
#      87                     validation_data=val_gen,
#      88                     validation_steps=128,
#      89                     epochs=1,
#      90                     class_weight = class_weights)
#      92 pred = model.predict_generator(test_gen)
#      94 y_true = test_gen.classes
#
# File /opt/conda/lib/python3.10/site-packages/keras/engine/training.py:2636, in Model.fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    2624 """Fits the model on data yielded batch-by-batch by a Python generator.
#    2625
#    2626 DEPRECATED:
#    2627   `Model.fit` now supports generators, so there is no longer any need to
#    2628   use this endpoint.
#    2629 """
#    2630 warnings.warn(
#    2631     "`Model.fit_generator` is deprecated and "
#    2632     "will be removed in a future version. "
#    2633     "Please use `Model.fit`, which supports generators.",
#    2634     stacklevel=2,
#    2635 )
# -> 2636 return self.fit(
#    2637     generator,
#    2638     steps_per_epoch=steps_per_epoch,
#    2639     epochs=epochs,
#    2640     verbose=verbose,
#    2641     callbacks=callbacks,
#    2642     validation_data=validation_data,
#    2643     validation_steps=validation_steps,
#    2644     validation_freq=validation_freq,
#    2645     class_weight=class_weight,
#    2646     max_queue_size=max_queue_size,
#    2647     workers=workers,
#    2648     use_multiprocessing=use_multiprocessing,
#    2649     shuffle=shuffle,
#    2650     initial_epoch=initial_epoch,
#    2651 )
#
# File /opt/conda/lib/python3.10/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /opt/conda/lib/python3.10/site-packages/keras/engine/training.py:1685, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1677 with tf.profiler.experimental.Trace(
#    1678     "train",
#    1679     epoch_num=epoch,
#    (...)
#    1682     _r=1,
#    1683 ):
#    1684     callbacks.on_train_batch_begin(step)
# -> 1685     tmp_logs = self.train_function(iterator)
#    1686     if data_handler.should_sync:
#    1687         context.async_wait()
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:894, in Function.__call__(self, *args, **kwds)
#     891 compiler = "xla" if self._jit_compile else "nonXla"
#     893 with OptionalXlaContext(self._jit_compile):
# --> 894   result = self._call(*args, **kwds)
#     896 new_tracing_count = self.experimental_get_tracing_count()
#     897 without_tracing = (tracing_count == new_tracing_count)
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:926, in Function._call(self, *args, **kwds)
#     923   self._lock.release()
#     924   # In this case we have created variables on the first call, so we run the
#     925   # defunned version which is guaranteed to never create variables.
# --> 926   return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     927 elif self._variable_creation_fn is not None:
#     928   # Release the lock early so that multiple threads can perform the call
#     929   # in parallel.
#     930   self._lock.release()
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py:143, in TracingCompiler.__call__(self, *args, **kwargs)
#     140 with self._lock:
#     141   (concrete_function,
#     142    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 143 return concrete_function._call_flat(
#     144     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py:1757, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1753 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1754 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1755     and executing_eagerly):
#    1756   # No tape is watching; skip to running the function.
# -> 1757   return self._build_call_outputs(self._inference_function.call(
#    1758       ctx, args, cancellation_manager=cancellation_manager))
#    1759 forward_backward = self._select_forward_and_backward_functions(
#    1760     args,
#    1761     possible_gradient_type,
#    1762     executing_eagerly)
#    1763 forward_function, args_with_tangents = forward_backward.forward()
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py:381, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     379 with _InterpolateFunctionError(self):
#     380   if cancellation_manager is None:
# --> 381     outputs = execute.execute(
#     382         str(self.signature.name),
#     383         num_outputs=self._num_outputs,
#     384         inputs=args,
#     385         attrs=attrs,
#     386         ctx=ctx)
#     387   else:
#     388     outputs = execute.execute_with_cancellation(
#     389         str(self.signature.name),
#     390         num_outputs=self._num_outputs,
#    (...)
#     393         ctx=ctx,
#     394         cancellation_manager=cancellation_manager)
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/eager/execute.py:52, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50 try:
#      51   ctx.ensure_initialized()
# ---> 52   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                       inputs, attrs, num_outputs)
#      54 except core._NotOkStatusException as e:
#      55   if name is not None:
#
# KeyboardInterrupt:

# %%
test_datagenerator = ImageDataGenerator(preprocessing_function = preprocess_input)

test_gen = test_datagenerator.flow_from_directory(        
                directory= os.path.join("Warp-C", "test"),
                target_size = (224, 224),
                color_mode = 'rgb',
                shuffle = False)
# Out:
# Found 1521 images belonging to 4 classes.
# {'cardboard': 0, 'glass': 1, 'metal': 2, 'plastic': 3}

# %%
dir(test_gen)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__next__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_filepaths',
#  '_flow_index',
#  '_get_batches_of_transformed_samples',
#  '_keras_api_names',
#  '_keras_api_names_v1',
#  '_set_index_array',
#  'allowed_class_modes',
#  'batch_index',
#  'batch_size',
#  'class_indices',
#  'class_mode',
#  'classes',
#  'color_mode',
#  'data_format',
#  'directory',
#  'dtype',
#  'filenames',
#  'filepaths',
#  'image_data_generator',
#  'image_shape',
#  'index_array',
#  'index_generator',
#  'interpolation',
#  'keep_aspect_ratio',
#  'labels',
#  'lock',
#  'n',
#  'next',
#  'num_classes',
#  'on_epoch_end',
#  'reset',
#  'Warp-C/test/glass/test_crops_bottle_glass-dark_prepared_data_all_MGS-05-Nov_02-57-30_01.jpg',
#  'Warp-C/test/glass/test_crops_bottle_glass-dark_prepared_data_all_MGS-05-Nov_04-05-55_01.jpg',
#  'Warp-C/test/glass/test_crops_bottle_glass-dark_prepared_data_all_MGS-27-Oct_08-34-01_01.jpg',
#  'Warp-C/test/glass/test_crops_bottle_glass-dark_prepared_data_all_MGS-27-Oct_09-37-37_01.jpg',
#  'Warp-C/test/glass/test_crops_bottle_glass-dark_prepared_data_all_MGS-27-Oct_09-48-43_01.jpg',
#  'Warp-C/test/glass/test_crops_bottle_glass-dark_prepared_data_all_MGS-27-Oct_09-48-43_02.jpg',
#  'Warp-C/test/glass/test_crops_bottle_glass-dark_prepared_data_all_MGS-27-Oct_15-57-48_01.jpg',
#  'Warp-C/test/glass/test_crops_bottle_glass-dark_prepared_data_all_MGS-27-Oct_16-38-05_01.jpg',
#  'Warp-C/test/glass/test_crops_bottle_glass-dark_prepared_data_all_MGS-27-Oct_17-07-15_01.jpg',
#  'Warp-C/test/glass/test_crops_bottle_glass-dark_prepared_data_all_MGS-27-Oct_23-39-18_01.jpg',
#  'Warp-C/test/glass/test_crops_bottle_glass-dark_prepared_data_all_MGS-28-Oct_00-25-02_01.jpg',
#  'Warp-C/test/glass/test_crops_bottle_glass-dark_prepared_data_all_MGS-28-Oct_00-37-07_01.jpg',
#  'Warp-C/test/glass/test_crops_bottle_glass-dark_prepared_data_all_MGS-28-Oct_00-50-04_01.jpg',
#  'Warp-C/test/glass/test_crops_bottle_glass-dark_prepared_data_all_MGS-28-Oct_03-08-33_01.jpg',
#  'Warp-C/test/glass/test_crops_bottle_glass-dark_prepared_data_all_MGS_19-Oct_18-54-39_01.jpg',
#  'Warp-C/test/glass/test_crops_bottle_glass-dark_prepared_data_all_MGS_19-Oct_19-01-15_01.jpg',
#  'Warp-C/test/glass/test_crops_bottle_glass-dark_prepared_data_all_MGS_19-Oct_19-16-13_01.jpg',
#  'Warp-C/test/glass/test_crops_bottle_glass-dark_prepared_data_all_MGS_19-Oct_21-14-46_01.jpg',
#  'Warp-C/test/glass/test_crops_bottle_glass-dark_prepared_data_all_MGS_19-Oct_21-29-58_01.jpg',
#  'Warp-C/test/glass/test_crops_bottle_glass-dark_prepared_data_all_MGS_20-Oct_00-55-13_01.jpg',
#  'Warp-C/test/glass/test_crops_bottle_glass-green_Monitoring_photo_2_test_25-Mar_12-04-03_01.jpg',
#  'Warp-C/test/glass/test_crops_bottle_glass-green_Monitoring_photo_2_test_25-Mar_14-18-01_01.jpg',
#  'Warp-C/test/glass/test_crops_bottle_glass-green_prepared_data_all_MGS-05-Nov_00-52-28_01.jpg',
#  'Warp-C/test/glass/test_crops_bottle_glass-green_prepared_data_all_MGS-05-Nov_00-52-28_02.jpg',
#  'Warp-C/test/glass/test_crops_bottle_glass-green_prepared_data_all_MGS-05-Nov_02-04-44_01.jpg',
#  'Warp-C/test/glass/test_crops_bottle_glass-green_prepared_data_all_MGS-05-Nov_02-50-13_01.jpg',
#  'Warp-C/test/glass/test_crops_bottle_glass-green_prepared_data_all_MGS-05-Nov_02-53-54_01.jpg',
#  'Warp-C/test/glass/test_crops_bottle_glass-green_prepared_data_all_MGS-05-Nov_02-55-15_01.jpg',
#  'Warp-C/test/glass/test_crops_bottle_glass-green_prepared_data_all_MGS-05-Nov_02-56-30_01.jpg',
#  'Warp-C/test/glass/test_crops_bottle_glass-green_prepared_data_all_MGS-05-Nov_04-18-21_01.jpg',
#  'Warp-C/test/glass/test_crops_bottle_glass-green_prepared_data_all_MGS-05-Nov_04-18-21_02.jpg',
#  'Warp-C/test/glass/test_crops_bottle_glass-green_prepared_data_all_MGS-05-Nov_04-21-21_01.jpg',
#  'Warp-C/test/glass/test_crops_bottle_glass-green_prepared_data_all_MGS-27-Oct_09-12-52_01.jpg',
#  'Warp-C/test/glass/test_crops_bottle_glass-green_prepared_data_all_MGS-27-Oct_14-00-43_01.jpg',
#  'Warp-C/test/glass/test_crops_bottle_glass-green_prepared_data_all_MGS-27-Oct_14-06-10_01.jpg',
#  'Warp-C/test/glass/test_crops_bottle_glass-green_prepared_data_all_MGS-27-Oct_17-01-04_01.jpg',
#  'Warp-C/test/glass/test_crops_bottle_glass-green_prepared_data_all_MGS-27-Oct_17-02-18_01.jpg',
#  'Warp-C/test/glass/test_crops_bottle_glass-green_prepared_data_all_MGS-28-Oct_00-37-35_01.jpg',
#  'Warp-C/test/glass/test_crops_bottle_glass-green_prepared_data_all_MGS_19-Oct_18-34-49_01.jpg',
#  'Warp-C/test/glass/test_crops_bottle_glass-green_prepared_data_all_MGS_19-Oct_19-06-14_01.jpg',
#  'Warp-C/test/glass/test_crops_bottle_glass-green_prepared_data_all_MGS_19-Oct_21-11-49_01.jpg',
#  'Warp-C/test/glass/test_crops_bottle_glass-green_prepared_data_all_MGS_19-Oct_21-29-58_01.jpg',
#  'Warp-C/test/glass/test_crops_bottle_glass-green_prepared_data_all_MGS_19-Oct_21-54-26_01.jpg',
#  'Warp-C/test/glass/test_crops_bottle_glass-green_prepared_data_all_MGS_19-Oct_22-08-19_01.jpg',
#  'Warp-C/test/glass/test_crops_bottle_glass-green_prepared_data_all_MGS_20-Oct_00-13-15_01.jpg',
#  'Warp-C/test/glass/test_crops_bottle_glass-transp_Monitoring_photo_test_25-Mar_12-25-08_01.jpg',
#  'Warp-C/test/glass/test_crops_bottle_glass-transp_prepared_data_all_MGS-05-Nov_00-52-28_01.jpg',
#  'Warp-C/test/glass/test_crops_bottle_glass-transp_prepared_data_all_MGS-05-Nov_00-54-51_01.jpg',
#  'Warp-C/test/glass/test_crops_bottle_glass-transp_prepared_data_all_MGS-05-Nov_00-55-12_01.jpg',
#  'Warp-C/test/glass/test_crops_bottle_glass-transp_prepared_data_all_MGS-05-Nov_00-55-12_02.jpg',
#  'Warp-C/test/glass/test_crops_bottle_glass-transp_prepared_data_all_MGS-05-Nov_01-49-15_01.jpg',
#  'Warp-C/test/glass/test_crops_bottle_glass-transp_prepared_data_all_MGS-05-Nov_01-53-17_01.jpg',
#  'Warp-C/test/glass/test_crops_bottle_glass-transp_prepared_data_all_MGS-05-Nov_02-04-44_01.jpg',
#  'Warp-C/test/glass/test_crops_bottle_glass-transp_prepared_data_all_MGS-05-Nov_02-38-55_01.jpg',
#  'Warp-C/test/glass/test_crops_bottle_glass-transp_prepared_data_all_MGS-05-Nov_02-47-40_01.jpg',
#  'Warp-C/test/glass/test_crops_bottle_glass-transp_prepared_data_all_MGS-05-Nov_02-54-27_01.jpg',
#  'Warp-C/test/glass/test_crops_bottle_glass-transp_prepared_data_all_MGS-05-Nov_03-50-31_01.jpg',
#  'Warp-C/test/glass/test_crops_bottle_glass-transp_prepared_data_all_MGS-05-Nov_03-50-37_01.jpg',
#  'Warp-C/test/glass/test_crops_bottle_glass-transp_prepared_data_all_MGS-05-Nov_03-52-29_01.jpg',
#  'Warp-C/test/glass/test_crops_bottle_glass-transp_prepared_data_all_MGS-05-Nov_03-53-11_01.jpg',
#  'Warp-C/test/glass/test_crops_bottle_glass-transp_prepared_data_all_MGS-05-Nov_04-18-21_01.jpg',
#  'Warp-C/test/glass/test_crops_bottle_glass-transp_prepared_data_all_MGS-27-Oct_08-33-17_01.jpg',
#  'Warp-C/test/glass/test_crops_bottle_glass-transp_prepared_data_all_MGS-27-Oct_08-34-01_01.jpg',
#  'Warp-C/test/glass/test_crops_bottle_glass-transp_prepared_data_all_MGS-27-Oct_09-12-52_01.jpg',
#  'Warp-C/test/glass/test_crops_bottle_glass-transp_prepared_data_all_MGS-27-Oct_09-36-39_01.jpg',
#  'Warp-C/test/glass/test_crops_bottle_glass-transp_prepared_data_all_MGS-27-Oct_09-48-43_01.jpg',
#  'Warp-C/test/glass/test_crops_bottle_glass-transp_prepared_data_all_MGS-27-Oct_14-06-10_01.jpg',
#  'Warp-C/test/glass/test_crops_bottle_glass-transp_prepared_data_all_MGS-27-Oct_16-44-00_01.jpg',
#  'Warp-C/test/glass/test_crops_bottle_glass-transp_prepared_data_all_MGS-27-Oct_17-03-17_01.jpg',
#  'Warp-C/test/glass/test_crops_bottle_glass-transp_prepared_data_all_MGS-27-Oct_23-58-29_01.jpg',
#  'Warp-C/test/glass/test_crops_bottle_glass-transp_prepared_data_all_MGS-28-Oct_00-17-45_01.jpg',
#  'Warp-C/test/glass/test_crops_bottle_glass-transp_prepared_data_all_MGS-28-Oct_00-25-02_01.jpg',
#  'Warp-C/test/glass/test_crops_bottle_glass-transp_prepared_data_all_MGS_19-Oct_18-53-53_01.jpg',
#  'Warp-C/test/glass/test_crops_bottle_glass-transp_prepared_data_all_MGS_19-Oct_18-54-39_01.jpg',
#  'Warp-C/test/glass/test_crops_bottle_glass-transp_prepared_data_all_MGS_19-Oct_20-17-12_01.jpg',
#  'Warp-C/test/glass/test_crops_bottle_glass-transp_prepared_data_all_MGS_19-Oct_21-29-58_01.jpg',
#  'Warp-C/test/glass/test_crops_bottle_glass-transp_prepared_data_all_MGS_19-Oct_21-35-52_01.jpg',
#  'Warp-C/test/plastic/test_crops_bottle_bottle-oil_POSAD_1_11-Sep_18-14-21_01.jpg',
#  'Warp-C/test/plastic/test_crops_bottle_bottle-oil_POSAD_1_12-Sep_10-13-41_01.jpg',
#  'Warp-C/test/plastic/test_crops_bottle_bottle-oil_POSAD_1_12-Sep_11-09-35_01.jpg',
#  'Warp-C/test/plastic/test_crops_bottle_bottle-oil_POSAD_1_12-Sep_14-17-46_01.jpg',
#  'Warp-C/test/plastic/test_crops_bottle_bottle-oil_POSAD_1_12-Sep_15-09-28_01.jpg',
#  'Warp-C/test/plastic/test_crops_bottle_bottle-oil_POSAD_1_12-Sep_16-43-03_01.jpg',
#  'Warp-C/test/plastic/test_crops_bottle_bottle-oil_POSAD_1_12-Sep_20-15-33_01.jpg',
#  ...]

# %%
    datagenerator_very_aug = ImageDataGenerator(
        preprocessing_function=preprocess_input,
        horizontal_flip=True,
        rotation_range=20,
        zoom_range=[0, 1.25],
        width_shift_range=0.2,
        height_shift_range=0.2,
        validation_split=0.2,
)
    
    train_gen = datagenerator_very_aug.flow_from_directory(
                directory= os.path.join("Warp-C", "train"),
                target_size = (224, 224),
                color_mode = 'rgb',
                classes = ['cardboard', 'glass', 'metal', 'plastic'],
                shuffle = True, 
                save_to_dir = 'augmented_images',
                save_prefix = 'augmented',
                subset = 'training')

    val_gen = datagenerator_very_aug.flow_from_directory(
                directory= os.path.join("Warp-C", "train"),
                target_size = (224, 224),
                color_mode = 'rgb',
                shuffle = True, 
                save_to_dir = 'augmented_images',
                save_prefix = 'augmented',
                subset = 'validation')
# Out:
# Found 7060 images belonging to 4 classes.
# Found 1763 images belonging to 4 classes.

# %%
test_gen.reset()

# %%
np.unique(test_gen.classes, return_counts = True)
# Out:
# (array([0, 1, 2, 3], dtype=int32), array([ 162,   86,   98, 1175]))

# %%
test_card = os.listdir(os.path.join("Warp-C", "test", "cardboard"))

# %%
files = test_gen.filenames[0:162]

len(files)
# Out:
# 162

# %%
# Out:
# False

# %% [markdown]
# ['test_crops_cardboard_milk-cardboard_Monitoring_photo_test_25-Mar_11-13-24_01.jpg',

# %% [markdown]
# 'cardboard/test_crops_cardboard_juice-cardboard_Monitoring_photo_2_test_25-Mar_11-28-21_01.jpg'

# %%
train_gen.filenames[0]
# Out:
# 'cardboard/train_crops_cardboard_juice-cardboard_POSAD_1_13-Sep_05-38-54_02.jpg'

# %% [markdown]
# train_crops_cardboard_juice-cardboard_Monitoring_photo_04-Mar_04-26-41_01.jpg

# %%
test_card = sorted(os.listdir(os.path.join("Warp-C", "test", "cardboard")))

# %%
test_card[0]
# Out:
# '.ipynb_checkpoints'

# %%
test_gen.reset()

# %%
test_gen.filenames[100]
# Out:
# 'cardboard/test_crops_cardboard_milk-cardboard_Monitoring_photo_test_25-Mar_11-16-54_01.jpg'

# %%
test_gen.filenames[0] == test_card[1]
# Out:
# False

# %%
type(test_gen.filenames[0])
# Out:
# str

# %%
test_card[101]
# Out:
# 'test_crops_cardboard_milk-cardboard_Monitoring_photo_test_25-Mar_11-16-54_01.jpg'
